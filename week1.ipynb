# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\91911\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\91911\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
img=cv2.imread("img1.jpg")

# %%
cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
i1=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray_image",i1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
i2=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
cv2.imshow("HSV_image",i2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
i3=cv2.cvtColor(i2,cv2.COLOR_HSV2BGR)
cv2.imshow("BGR from hsv",i3)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
edge = cv2.Canny(img,100,200) 
cv2.imshow('original', img) 
cv2.imshow('edge', edge) 
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
cv2.line(i3, (20, 160), (500, 160), (0, 0, 255), 10) 
cv2.imshow("Drawing a line",i3)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
img2 = np.zeros((400, 400, 3), dtype = "uint8") 
cv2.rectangle(img2, (30, 30), (300, 200), (255, 0, 0), 5) 
cv2.imshow('rectangle', img2) 
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
img3 = np.zeros((400, 400, 3), dtype = "uint8") 
cv2.circle(img3, (200, 200), 80, (255, 0, 0), 3) 
cv2.imshow('circle', img3) 
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
half = cv2.resize(img, (0, 0), fx = 0.3, fy = 0.8)
cv2.imshow('resizedinto half',half) 
cv2.imshow('original',img) 
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
flip = cv2.flip(img,-1)
cv2.imshow('flipped image',flip) 
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
h, w = img.shape[:2]
rotation_matrix = cv2.getRotationMatrix2D((h//2,w//2), 30, 1.0)
rotate= cv2.warpAffine(img, rotation_matrix, (w,h))
cv2.imshow('Rotated image',rotate) 
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt  

fig = plt.figure(figsize=(10, 7))
image1 = cv2.imread('i1.jpg')
image2 = cv2.imread('i2.jpg')
image3 = cv2.imread('i3.jpg')
image4 = cv2.imread('i4.jpg')

image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)
image3 = cv2.cvtColor(image3, cv2.COLOR_BGR2RGB)
image4 = cv2.cvtColor(image4, cv2.COLOR_BGR2RGB)

plt.subplot(2, 2, 1) 
plt.imshow(image1)  
plt.axis('off') 
plt.title("Image 1") 

plt.subplot(2, 2, 2)  
plt.imshow(image2)  
plt.axis('off')  
plt.title("Image 2") 

plt.subplot(2, 2, 3)  
plt.imshow(image3) 
plt.axis('off') 
plt.title("Image 3")  

plt.subplot(2, 2, 4) 
plt.imshow(image4)  
plt.axis('off')  
plt.title("Image 4")  

plt.show()
